# %%
import pandas as pd
import numpy as np
import yahooquery as yq
import yfinance as yf

# %%
pd_fiis = pd.read_csv('statusinvest-busca-avancada.csv', sep=';')
len(pd_fiis['TICKER'])
# Out:
# 579

# %%
s = yq.Screener()

lista_screeners = ['reit_diversified',
    'reit_healthcare_facilities',
    'reit_hotel_motel',
    'reit_industrial',
    'reit_office',
   'reit_residential',
   'reit_retail']

lista_cod_reits = []
reits = s.get_screeners(lista_screeners, 100)
pd_reits = pd.DataFrame(reits)
json_reit_diversified = pd_reits.iloc[9]

for reit in json_reit_diversified:
    for item in reit:
        lista_cod_reits.append(item['symbol'])

len(lista_cod_reits)
# Out:
# 189

# %% [markdown]
# # Achar o simbolo de cada REIT

# %%
pd_reits.iloc[9]['reit_diversified'][1]
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'lastCloseTevEbitLtm': 24.417681,
#  'lastClosePriceToNNWCPerShare': -1.5784169914930295,
#  'currency': 'USD',
#  'regularMarketChangePercent': -0.523065,
#  'exchange': 'NYQ',
#  'fiftyTwoWeekHigh': 66.1,
#  'fiftyTwoWeekLow': 52.91,
#  'averageAnalystRating': '3.0 - Hold',
#  'dividendYield': 5.67,
#  'shortName': 'W. P. Carey Inc. REIT',
#  'bid': 62.0,
#  'ask': 65.0,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 885393000000,
#  'priceHint': 2,
#  'preMarketChange': 0.7799988,
#  'preMarketChangePercent': 1.2436205,
#  'preMarketTime': 1748865601,
#  'preMarketPrice': 63.5,
#  'regularMarketChange': -0.330002,
#  'regularMarketTime': 1748635202,
#  'regularMarketPrice': 62.76,
#  'regularMarketDayHigh': 62.94,
#  'regularMarketDayRange': '62.345 - 62.94',
#  'regularMarketDayLow': 62.345,
#  'regularMarketVolume': 903725,
#  'regularMarketPreviousClose': 63.09,
#  'bidSize': 2,
#  'askSize': 3,
#  'market': 'us_market',
#  'messageBoardId': 'finmb_24043',
#  'fullExchangeName': 'NYSE',
#  'longName': 'W. P. Carey Inc.',
#  'financialCurrency': 'USD',
#  'regularMarketOpen': 62.61,
#  'averageDailyVolume3Month': 1298398,
#  'averageDailyVolume10Day': 1439820,
#  'corporateActions': [],
#  'fiftyTwoWeekLowChange': 9.849998,
#  'fiftyTwoWeekLowChangePercent': 0.18616515,
#  'fiftyTwoWeekRange': '52.91 - 66.1',
#  'fiftyTwoWeekHighChange': -3.3400002,
#  'fiftyTwoWeekHighChangePercent': -0.050529506,
#  'fiftyTwoWeekChangePercent': 11.672592,
#  'dividendDate': 1744675200,
#  'earningsTimestamp': 1745957103,
#  'earningsTimestampStart': 1753819200,
#  'earningsTimestampEnd': 1753819200,
#  'earningsCallTimestampStart': 1746025200,
#  'earningsCallTimestampEnd': 1746025200,
#  'isEarningsDateEstimate': True,
#  'trailingAnnualDividendRate': 3.515,
#  'trailingPE': 32.350513,
#  'dividendRate': 3.56,
#  'trailingAnnualDividendYield': 0.05571406,
#  'marketState': 'PRE',
#  'epsTrailingTwelveMonths': 1.94,
#  'epsForward': 2.19,
#  'epsCurrentYear': 2.38495,
#  'priceEpsCurrentYear': 26.315018,
#  'sharesOutstanding': 218976000,
#  'bookValue': 38.189,
#  'fiftyDayAverage': 61.0866,
#  'fiftyDayAverageChange': 1.6733971,
#  'fiftyDayAverageChangePercent': 0.027393848,
#  'twoHundredDayAverage': 59.12065,
#  'twoHundredDayAverageChange': 3.639347,
#  'twoHundredDayAverageChangePercent': 0.061557967,
#  'marketCap': 13742932992,
#  'forwardPE': 28.657534,
#  'priceToBook': 1.6434052,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'esgPopulated': False,
#  'tradeable': False,
#  'cryptoTradeable': False,
#  'displayName': 'W. P. Carey',
#  'symbol': 'WPC'}

# %%
for reits_data in pd_reits.iloc[9]['reit_diversified']:
    print(reits_data)
    for index in range(len(reits_data)):
        print(index)
        print(reits_data[index])
# Out:
# {'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': False, 'customPriceAlertConfidence': 'LOW', 'lastCloseTevEbitLtm': 13.868526, 'lastClosePriceToNNWCPerShare': -1.8423615873417643, 'currency': 'USD', 'regularMarketChangePercent': 0.126299, 'exchange': 'NYQ', 'fiftyTwoWeekHigh': 34.29, 'fiftyTwoWeekLow': 27.53, 'averageAnalystRating': '1.5 - Buy', 'dividendYield': 5.46, 'shortName': 'VICI Properties Inc.', 'bid': 0.0, 'ask': 0.0, 'hasPrePostMarketData': True, 'firstTradeDateMilliseconds': 1514903400000, 'priceHint': 2, 'preMarketChange': -0.23999977, 'preMarketChangePercent': -0.75733596, 'preMarketTime': 1748865627, 'preMarketPrice': 31.45, 'regularMarketChange': 0.039999, 'regularMarketTime': 1748635202, 'regularMarketPrice': 31.71, 'regularMarketDayHigh': 31.85, 'regularMarketDayRange': '31.435 - 31.85', 'regularMarketDayLow': 31.435, 'regularMarketVolume': 10946790, 'regularMarketPreviousClose': 31.67, 'bidSize': 13, 'askSize': 5, 'market': 'us_market', 'messageBoardId': 'finmb_430871960', 'fullExchangeName': 'NYSE', 'longName': 'VICI Properties Inc.', 'financialCurrency': 'USD', 'regularMarketOpen': 31.62, 'averageDailyVolume3Month': 7533314, 'averageDailyVolume10Day': 5843650, 'corporateActions': [], 'fiftyTwoWeekLowChange': 4.1799984, 'fiftyTwoWeekLowChangePercent': 0.1518343, 'fiftyTwoWeekRange': '27.53 - 34.29', 'fiftyTwoWeekHighChange': -2.5800018, 'fiftyTwoWeekHighChangePercent': -0.07524065, 'fiftyTwoWeekChangePercent': 10.218978, 'dividendDate': 1743638400, 'earningsTimestamp': 1746044100, 'earningsTimestampStart': 1753905600, 'earningsTimestampEnd': 1753905600, 'earningsCallTimestampStart': 1746108000, 'earningsCallTimestampEnd': 1746108000, 'isEarningsDateEstimate': True, 'trailingAnnualDividendRate': 1.713, 'trailingPE': 12.684, 'dividendRate': 1.73, 'trailingAnnualDividendYield': 0.054089043, 'marketState': 'PRE', 'epsTrailingTwelveMonths': 2.5, 'epsForward': 2.73, 'epsCurrentYear': 2.78, 'priceEpsCurrentYear': 11.406475, 'sharesOutstanding': 1056710016, 'bookValue': 25.182, 'fiftyDayAverage': 31.7, 'fiftyDayAverageChange': 0.0099983215, 'fiftyDayAverageChangePercent': 0.00031540447, 'twoHundredDayAverage': 31.61695, 'twoHundredDayAverageChange': 0.09305, 'twoHundredDayAverageChangePercent': 0.0029430417, 'marketCap': 33508274176, 'forwardPE': 11.615384, 'priceToBook': 1.2592328, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'gmtOffSetMilliseconds': -14400000, 'esgPopulated': False, 'tradeable': False, 'cryptoTradeable': False, 'displayName': 'VICI Properties', 'symbol': 'VICI'}
# 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 5
#       3 for index in range(len(reits_data)):
#       4     print(index)
# ----> 5     print(reits_data[index])
#
# KeyError: 0

# %%
hasgx = yq.Ticker('hasgx')

# %%
hasgx.fund_profile
# Out:
# {'hasgx': {'maxAge': 1,
#   'styleBoxUrl': 'https://s.yimg.com/lq/i/fi/3_0stylelargeeq9.gif',
#   'family': 'Harbor',
#   'categoryName': 'Small Growth',
#   'legalType': None,
#   'managementInfo': {'managerName': 'William A. Muggia',
#    'managerBio': 'President, Chief Executive Officer and Chief Investment Officer\nMarket Outlook, Strategy, & Portfolio Management\n1994-Present: Westfield Capital Management \n1992-1994: Alex. Brown & Sons\n1983-1990: Kidder Peabody & Co. \n1992: Harvard Business School, MBA \n1983: Middlebury College',
#    'startdate': 973036800},
#   'feesExpensesInvestment': {'annualReportExpenseRatio': 0.0088,
#    'netExpRatio': 0.0088,
#    'grossExpRatio': 0.0088,
#    'projectionValues': {'5y': 0.0, '3y': 0.0, '10y': 0.0}},
#   'feesExpensesInvestmentCat': {'annualReportExpenseRatio': 0.0121,
#    'frontEndSalesLoad': 0.054,
#    'deferredSalesLoad': 0.0127,
#    'projectionValuesCat': {'5y': 819.78, '3y': 499.51, '10y': 1704.89}},
#   'initInvestment': 50000.0,
#   'subseqInvestment': 0.0,
#   'brokerages': ['TradeStation Securities',
#    'Ausdal Financial Partners Inc',
#    'Cetera Advisors LLC',
#    'Cetera Advisor Networks LLC',
#    'Pruco Securities, LLC',
#    'UBS Financial Services Inc',
#    'Protected Investors of America',
#    'Comerica Bank',
#    'E TRADE Financial',
#    'Mid Atlantic Capital Corp',
#    'Morgan Stanley - Brokerage Accounts',
#    'Pershing FundCenter',
#    'Schwab Institutional',
#    'Shareholders Services Group',
#    'JPMorgan',
#    'Merrill Lynch',
#    'Vanguard',
#    'T. Rowe Price',
#    'TD Ameritrade Trust Company',
#    '(Junk)CommonWealth PPS',
#    'LPL SAM Eligible - 10.24.2024',
#    'Fidelity Retail FundsNetwork',
#    'Fidelity Retail FundsNetwork-NTF',
#    'Fidelity Institutional FundsNetwork',
#    'Fidelity Institutional FundsNetwork-NTF',
#    'DATALynx',
#    'DATALynx NTF',
#    'PruChoice Investments',
#    'Dreyfus NTF',
#    'Ameriprise Brokerage',
#    'Federated TrustConnect',
#    'Federated TrustConnect NTF',
#    'Cetera Advisors LLC- PAM, PRIME, Premier',
#    'Cetera Advisor Networks LLC- PAM, PRIME, Premier',
#    'RBC Wealth Management-Advisory Eligible',
#    'Ameriprise SPS Advantage',
#    'CommonWealth NTF',
#    'SunAmerica Securities Premier / Pinnacle',
#    'Vanguard NTF',
#    'ETrade No Load Fee',
#    'SunGard Transaction Network',
#    'Raymond James',
#    'Raymond James WRAP Eligible',
#    'Bear Stearns No-Load Transaction Fee',
#    'Commonwealth Universe',
#    'FTJ FundChoice',
#    'Robert W. Baird & Co.',
#    'DATALynx IMS',
#    'JPMorgan INVEST',
#    'WFA MF Advisory Updated 5.1.25',
#    'RBC Wealth Management-Network Eligible',
#    'DailyAccess Corporation RTC',
#    'DailyAccess Corporation FRIAG',
#    'WR Hambrecht Co LLC',
#    'Sterne, Agee & Leach, Inc.,',
#    'JPMorgan INVEST NTF',
#    'ING Financial Ptnrs PAM and PRIME Approv',
#    'Ameritas NTFN',
#    'Ameritas NTF P',
#    'Firstrade',
#    'Scottrade TF',
#    'Scottrade NTF',
#    'Standard Retirement Services, Inc.',
#    'TIAA-CREF Brokerage Services',
#    'Fidelity Advisor 401(k) I Shares',
#    'Thrivent – Advisory Eligible',
#    'Pershing FundVest NTF',
#    'Morgan Stanley Consulting Group Advisor',
#    'Matrix Financial Solutions',
#    'Trade PMR Transaction Fee',
#    'Trade PMR NTF',
#    'DWS Retirement Sevs Investment Offerings',
#    'TD Ameritrade Retail',
#    'TD Ameritrade Institutional',
#    'ING Financial Advisers - SAS Funds',
#    'NYLIM 401(k) Complete',
#    'Met Life Resources MFSP Alliance List',
#    'ADP Access',
#    'Mid Atlantic Capital Group',
#    'HD Vest - Vest Advisor',
#    'Securities America Advisors',
#    'Bear Stearns',
#    'JP MORGAN NO-LOAD NTF',
#    'JP MORGAN NTF',
#    'JP MORGAN NO-LOAD TRANSACTION FEE',
#    'TD Ameritrade Retail NTF',
#    'TD Ameritrade Institutional NTF',
#    'TIAA-CREF NTF',
#    'MSWM Brokerage',
#    'WFA Fdntl Choice/PIM Updated 5.1.25',
#    'ADP Access Open Fund Architecture',
#    'ADP Access Tier 1',
#    'DailyAccess Corporation Mid-Atlantic',
#    'Waddell & Reed Choice MAP Flex',
#    'Investacorp NTF',
#    'ING Financial Partners Inc.',
#    'Securities America Inc.',
#    'Zhejiang Akcome New Energy Technology Co Ltd',
#    'Vanguard TF',
#    'Morgan Stanley Portfolio Management',
#    'JP Morgan No Load',
#    'Merrill Edge',
#    'DailyAccess Corporation Matrix',
#    'DailyAccess Corporation MATC',
#    'Cetera Financial Specialists LLC- Premier',
#    'LPL SWM - 10.24.2024',
#    'Schwab All (Retail, Instl, Retirement)',
#    'Schwab Retirement Only',
#    'Schwab Existing Shareholders Only',
#    'Schwab OneSource & NTF (No Load & No Transaction Fee)',
#    'Pershing Retirement Plan Network',
#    'Ameriprise SPS Advisor',
#    'HD Vest',
#    'Kestra Financial',
#    'Commonwealth (PPS Access Program)',
#    'Commonwealth (NTF - PPS/Advisory)',
#    'Commonwealth (PPS/Advisory)',
#    'ADP Advisor Access 3(21) Tier 0',
#    'ADP Advisor Access 3(21) Tier 1',
#    'ADP Advisor Access Tier 0',
#    'ADP Advisor Access Tier 1',
#    'LPL Brokerage Availability - November 2024',
#    'Pruco Securities LLC -PruChoice Mutual Funds',
#    'Pruco Securities LLC -PruUMA’s Mutual Funds',
#    'Avantax',
#    'Allowab (non-advisory)',
#    'Mid Atlantic Clearing and Settlement']}}

# %%
hasgx_performance = hasgx.fund_performance
hasgx_performance
# Out:
# {'hasgx': {'maxAge': 1,
#   'fundCategoryName': 'Small Growth',
#   'performanceOverview': {'asOfDate': '2025-05-22 21:00:00',
#    'morningStarReturnRating': 0.0,
#    'ytdReturnPct': -0.057265602,
#    'fiveYrAvgReturnPct': 0.0825278,
#    'numYearsUp': 18,
#    'numYearsDown': 6,
#    'bestOneYrTotalReturn': 0.44779998,
#    'bestThreeYrTotalReturn': 0.44779998,
#    'worstThreeYrTotalReturn': -0.0017,
#    'oneYearTotalReturn': 0.0010257,
#    'threeYearTotalReturn': 0.0738547},
#   'performanceOverviewCat': {'ytdReturnPct': 0.124,
#    'fiveYrAvgReturnPct': 0.20719999,
#    'oneYearTotalReturn': 0.55689996,
#    'threeYearTotalReturn': 0.1934},
#   'loadAdjustedReturns': {'oneYear': -0.0257125,
#    'threeYear': 0.0365459,
#    'fiveYear': 0.0875721,
#    'tenYear': 0.0781325},
#   'trailingReturns': {'asOfDate': '2025-05-22 21:00:00',
#    'ytd': -0.1073729,
#    'oneMonth': -0.0031974,
#    'threeMonth': -0.1405927,
#    'oneYear': -0.0257125,
#    'threeYear': 0.0365459,
#    'fiveYear': 0.0875721,
#    'tenYear': 0.0781325,
#    'lastBullMkt': 0.1977359,
#    'lastBearMkt': -0.1798507},
#   'trailingReturnsNav': {'ytd': 0.0,
#    'oneMonth': 0.0,
#    'threeMonth': 0.0,
#    'oneYear': 0.0,
#    'threeYear': 0.0,
#    'fiveYear': 0.0,
#    'tenYear': 0.0},
#   'trailingReturnsCat': {'ytd': 0.124,
#    'oneMonth': 0.0337,
#    'threeMonth': 0.048800003,
#    'oneYear': 0.55689996,
#    'threeYear': 0.1934,
#    'fiveYear': 0.20719999,
#    'tenYear': 0.1398,
#    'lastBullMkt': 0.2785,
#    'lastBearMkt': -0.24059999},
#   'annualTotalReturns': {'returns': [{'year': '2025'},
#     {'year': '2024', 'annualValue': 0.0931333},
#     {'year': '2023', 'annualValue': 0.22202249},
#     {'year': '2022', 'annualValue': -0.2552561},
#     {'year': '2021', 'annualValue': 0.0976617},
#     {'year': '2020', 'annualValue': 0.3839114},
#     {'year': '2019', 'annualValue': 0.4233321},
#     {'year': '2018', 'annualValue': -0.107390605},
#     {'year': '2017', 'annualValue': 0.2460054},
#     {'year': '2016', 'annualValue': 0.062196396},
#     {'year': '2015', 'annualValue': -0.013101799},
#     {'year': '2014', 'annualValue': 0.0828115},
#     {'year': '2013', 'annualValue': 0.4478411},
#     {'year': '2012', 'annualValue': 0.1447442},
#     {'year': '2011', 'annualValue': -0.0766004},
#     {'year': '2010', 'annualValue': 0.3168667},
#     {'year': '2009', 'annualValue': 0.4008322},
#     {'year': '2008', 'annualValue': -0.4041542},
#     {'year': '2007', 'annualValue': 0.1363713},
#     {'year': '2006', 'annualValue': 0.1087122},
#     {'year': '2005', 'annualValue': 0.0564466},
#     {'year': '2004', 'annualValue': 0.1115022},
#     {'year': '2003', 'annualValue': 0.4439252},
#     {'year': '2002', 'annualValue': -0.200747},
#     {'year': '2001', 'annualValue': 0.0229226}],
#    'returnsCat': [{'year': '2020', 'annualValue': 0.3862273},
#     {'year': '2019', 'annualValue': 0.27676532},
#     {'year': '2018', 'annualValue': -0.0576395},
#     {'year': '2017', 'annualValue': 0.2150002},
#     {'year': '2016', 'annualValue': 0.111996695},
#     {'year': '2015', 'annualValue': -0.0241295},
#     {'year': '2014', 'annualValue': 0.024365399},
#     {'year': '2013', 'annualValue': 0.40909082},
#     {'year': '2012', 'annualValue': 0.1314999},
#     {'year': '2011', 'annualValue': -0.0355412},
#     {'year': '2010', 'annualValue': 0.2698293},
#     {'year': '2009', 'annualValue': 0.3545617},
#     {'year': '2008', 'annualValue': -0.41551048},
#     {'year': '2007', 'annualValue': 0.075887196},
#     {'year': '2006', 'annualValue': 0.1081437},
#     {'year': '2005', 'annualValue': 0.060230598},
#     {'year': '2004', 'annualValue': 0.12409429},
#     {'year': '2003', 'annualValue': 0.45537603},
#     {'year': '2002', 'annualValue': -0.2787935},
#     {'year': '2001', 'annualValue': -0.0891243},
#     {'year': '2000', 'annualValue': -0.0384997},
#     {'year': '1999', 'annualValue': 0.64770126},
#     {'year': '1998', 'annualValue': 0.0523461},
#     {'year': '1997', 'annualValue': 0.1741466},
#     {'year': '1996', 'annualValue': 0.18674481},
#     {'year': '1995', 'annualValue': 0.3614976},
#     {'year': '1994', 'annualValue': -0.0051973998},
#     {'year': '1993', 'annualValue': 0.17361571},
#     {'year': '1992', 'annualValue': 0.1094542},
#     {'year': '1991', 'annualValue': 0.5725298},
#     {'year': '1990', 'annualValue': -0.0984044},
#     {'year': '1989', 'annualValue': 0.2626742},
#     {'year': '1988', 'annualValue': 0.18222731},
#     {'year': '1987', 'annualValue': -0.0370497},
#     {'year': '1986', 'annualValue': 0.099111795},
#     {'year': '1985', 'annualValue': 0.2643012},
#     {'year': '1984', 'annualValue': -0.104290105},
#     {'year': '1983', 'annualValue': 0.2495246},
#     {'year': '1982', 'annualValue': 0.2308341},
#     {'year': '1981', 'annualValue': 0.0207251},
#     {'year': '1980', 'annualValue': 0.3761657},
#     {'year': '1979', 'annualValue': 0.3690657},
#     {'year': '1978', 'annualValue': 0.1781299},
#     {'year': '1977', 'annualValue': 0.1065682},
#     {'year': '1976', 'annualValue': 0.3378357},
#     {'year': '1975', 'annualValue': 0.3783118},
#     {'year': '1974', 'annualValue': -0.3575943},
#     {'year': '1973', 'annualValue': -0.3001683},
#     {'year': '1972', 'annualValue': 0.1025676},
#     {'year': '1971', 'annualValue': 0.19541731},
#     {'year': '1970', 'annualValue': -0.1831704},
#     {'year': '1969', 'annualValue': -0.16133231},
#     {'year': '1968', 'annualValue': 0.1150183},
#     {'year': '1967', 'annualValue': 0.5074166},
#     {'year': '1966', 'annualValue': -0.0137236},
#     {'year': '1965', 'annualValue': 0.2515068},
#     {'year': '1964', 'annualValue': 0.100048},
#     {'year': '1963', 'annualValue': 0.1902171},
#     {'year': '1962', 'annualValue': -0.2464827},
#     {'year': '1961', 'annualValue': 0.35685748},
#     {'year': '1960', 'annualValue': 0.0359799},
#     {'year': '1959', 'annualValue': 0.1342513},
#     {'year': '1958', 'annualValue': 0.47772512},
#     {'year': '1957', 'annualValue': -0.17027621},
#     {'year': '1956', 'annualValue': 0.0318841},
#     {'year': '1955', 'annualValue': 0.1480865},
#     {'year': '1954', 'annualValue': 0.2599581},
#     {'year': '1953', 'annualValue': -0.0041754004},
#     {'year': '1952', 'annualValue': 0.098623894},
#     {'year': '1951', 'annualValue': 0.0927318},
#     {'year': '1950', 'annualValue': 0.1735294},
#     {'year': '1949', 'annualValue': 0.09324761},
#     {'year': '1948', 'annualValue': -0.0220126},
#     {'year': '1947', 'annualValue': -0.0154799}]},
#   'pastQuarterlyReturns': {'returns': [{'year': '2025', 'q1': -0.1045097},
#     {'year': '2024',
#      'q1': 0.0899471,
#      'q2': -0.056172,
#      'q3': 0.0940485,
#      'q4': -0.0287338},
#     {'year': '2023',
#      'q1': 0.0775623,
#      'q2': 0.0694087,
#      'q3': -0.0600962,
#      'q4': 0.12826121},
#     {'year': '2022',
#      'q1': -0.1213115,
#      'q2': -0.1798507,
#      'q3': -0.009099199,
#      'q4': 0.042915},
#     {'year': '2021',
#      'q1': 0.038376,
#      'q2': 0.0176754,
#      'q3': -0.0047367997,
#      'q4': 0.0436783},
#     {'year': '2020',
#      'q1': -0.23689881,
#      'q2': 0.3189087,
#      'q3': 0.109843105,
#      'q4': 0.23893869},
#     {'year': '2019',
#      'q1': 0.2161895,
#      'q2': 0.051136397,
#      'q3': -0.0162162,
#      'q4': 0.13173899},
#     {'year': '2018',
#      'q1': 0.0388619,
#      'q2': 0.0394122,
#      'q3': 0.0745501,
#      'q4': -0.23071171},
#     {'year': '2017',
#      'q1': 0.0800628,
#      'q2': 0.0363372,
#      'q3': 0.0406732,
#      'q4': 0.0696838},
#     {'year': '2016',
#      'q1': -0.0721992,
#      'q2': 0.029517,
#      'q3': 0.0834057,
#      'q4': 0.026420701},
#     {'year': '2015',
#      'q1': 0.0832127,
#      'q2': 0.012692099,
#      'q3': -0.14182061,
#      'q4': 0.0483423},
#     {'year': '2014',
#      'q1': 0.0207636,
#      'q2': -0.0013123,
#      'q3': -0.022339001,
#      'q4': 0.0864499},
#     {'year': '2013',
#      'q1': 0.1510549,
#      'q2': 0.043255102,
#      'q3': 0.0843289,
#      'q4': 0.1119194},
#     {'year': '2012',
#      'q1': 0.114889696,
#      'q2': -0.049464103,
#      'q3': 0.0633131,
#      'q4': 0.015890501},
#     {'year': '2011',
#      'q1': 0.0738151,
#      'q2': 0.0028944002,
#      'q3': -0.2590188,
#      'q4': 0.1571717},
#     {'year': '2010',
#      'q1': 0.0960396,
#      'q2': -0.089430906,
#      'q3': 0.140873,
#      'q4': 0.1565525},
#     {'year': '2009',
#      'q1': -0.0790569,
#      'q2': 0.1957831,
#      'q3': 0.1876574,
#      'q4': 0.0710498},
#     {'year': '2008',
#      'q1': -0.1254996,
#      'q2': 0.0585009,
#      'q3': -0.1200345,
#      'q4': -0.2684955},
#     {'year': '2007',
#      'q1': 0.0392465,
#      'q2': 0.0422961,
#      'q3': 0.026087001,
#      'q4': 0.0224132},
#     {'year': '2006',
#      'q1': 0.15329629,
#      'q2': -0.0716253,
#      'q3': -0.0333828,
#      'q4': 0.071273},
#     {'year': '2005',
#      'q1': -0.0541796,
#      'q2': 0.0515548,
#      'q3': 0.0529183,
#      'q4': 0.0088167},
#     {'year': '2004',
#      'q1': 0.0857605,
#      'q2': -0.009687,
#      'q3': -0.0579383,
#      'q4': 0.0972977},
#     {'year': '2003',
#      'q1': -0.029205598,
#      'q2': 0.2154031,
#      'q3': 0.0910891,
#      'q4': 0.1215971},
#     {'year': '2002',
#      'q1': 0.0289449,
#      'q2': -0.0825771,
#      'q3': -0.18397631,
#      'q4': 0.0375758},
#     {'year': '2001',
#      'q1': -0.1203438,
#      'q2': 0.1921824,
#      'q3': -0.1575592,
#      'q4': 0.15783781}]},
#   'rankInCategory': {'ytd': 45,
#    'oneMonth': 37,
#    'threeMonth': 44,
#    'oneYear': 77,
#    'threeYear': 52,
#    'fiveYear': 50},
#   'riskOverviewStatistics': {'riskRating': 3,
#    'riskStatistics': [{'year': '5y',
#      'alpha': -6.46,
#      'beta': 1.08,
#      'meanAnnualReturn': 0.88,
#      'rSquared': 71.78,
#      'stdDev': 20.62,
#      'sharpeRatio': 0.37,
#      'treynorRatio': 5.44},
#     {'year': '3y',
#      'alpha': -8.04,
#      'beta': 1.11,
#      'meanAnnualReturn': 0.48,
#      'rSquared': 74.3,
#      'stdDev': 21.11,
#      'sharpeRatio': 0.05,
#      'treynorRatio': -0.95},
#     {'year': '10y',
#      'alpha': -4.96,
#      'beta': 1.16,
#      'meanAnnualReturn': 0.8,
#      'rSquared': 77.6,
#      'stdDev': 20.21,
#      'sharpeRatio': 0.38,
#      'treynorRatio': 5.02}]},
#   'riskOverviewStatisticsCat': {'riskStatisticsCat': [{'year': '5y',
#      'alpha': 0.0063,
#      'beta': 0.0117999995,
#      'meanAnnualReturn': 0.0176,
#      'rSquared': 0.7331,
#      'stdDev': 0.2086,
#      'sharpeRatio': 0.0095999995,
#      'treynorRatio': 0.1666},
#     {'year': '3y',
#      'alpha': -0.0171,
#      'beta': 0.0121,
#      'meanAnnualReturn': 0.0175,
#      'rSquared': 0.7765,
#      'stdDev': 0.256,
#      'sharpeRatio': 0.0077,
#      'treynorRatio': 0.1506},
#     {'year': '10y',
#      'alpha': -0.0247,
#      'beta': 0.0117999995,
#      'meanAnnualReturn': 0.0124,
#      'rSquared': 0.7285,
#      'stdDev': 0.1889,
#      'sharpeRatio': 0.0076,
#      'treynorRatio': 0.1137}]}}}

# %% [markdown]
# ### Buscar todos os Reits disponiveis na API

# %%
lista_reits = []
for reit_sector in lista_screeners:
    for reits_data in pd_reits.iloc[9][reit_sector]:
            lista_reits.append(reits_data['symbol'])

print(lista_reits)
# Out:
# ['VICI', 'WPC', 'BNL', 'ESRT', 'GNL', 'AAT', 'GNL-PA', 'SAFE', 'AHH-PA', 'AHH', 'GOODO', 'GOOD', 'CTO', 'OLP', 'FVR', 'CTO-PA', 'GNL-PB', 'GNL-PD', 'GNL-PE', 'GOODN', 'NXDT-PA', 'WELL', 'VTR', 'DOC', 'OHI', 'CTRE', 'AHR', 'HR', 'SBRA', 'NHI', 'LTC', 'SILA', 'UHT', 'CHCT', 'GMRE', 'GMRE-PA', 'HST', 'RHP', 'RLJ-PA', 'APLE', 'PEB-PF', 'PEB-PE', 'PK', 'SHO', 'DRH', 'XHR', 'RLJ', 'PEB', 'INN-PE', 'CLDT', 'BHR-PD', 'BHR-PB', 'AHT-PD', 'AHT-PG', 'AHT-PI', 'AHT-PF', 'AHT-PH', 'AHT', 'CLDT-PA', 'DRH-PA', 'INN-PF', 'PEB-PG', 'PEB-PH', 'SHO-PH', 'SHO-PI', 'PLD', 'PSA', 'PSA-PH', 'EXR', 'PSA-PK', 'LINE', 'CUBE', 'EGP', 'REXR', 'FR', 'STAG', 'TRNO', 'NSA', 'COLD', 'REXR-PB', 'GRP-UN', 'LXP', 'NSA-PA', 'LXP-PC', 'IIPR', 'IIPR-PA', 'PLYM', 'MDV', 'MDV-PA', 'NSA-PB', 'PSA-PF', 'PSA-PG', 'PSA-PI', 'PSA-PJ', 'PSA-PL', 'PSA-PM', 'PSA-PN', 'PSA-PO', 'PSA-PP', 'PSA-PQ', 'PSA-PR', 'PSA-PS', 'REXR-PC', 'SMA', 'ARE', 'BXP', 'VNO-PL', 'VNO-PM', 'VNO', 'SLG-PI', 'CUZ', 'SLG', 'KRC', 'HIW', 'CDP', 'DEI', 'DEA', 'JBGS', 'PGRE', 'PDM', 'NLOP', 'PKST', 'PSTL', 'CIO-PA', 'HPP-PC', 'VNO-PN', 'VNO-PO', 'AVB', 'EQR', 'INVH', 'ESS', 'MAA', 'SUI', 'AMH', 'UDR', 'ELS', 'CPT', 'MAA-PI', 'AMH-PH', 'AMH-PG', 'IRT', 'NXRT', 'VRE', 'ELME', 'UMH', 'AIV', 'CSR', 'UMH-PD', 'BRT', 'MRP', 'SPG', 'SPG-PJ', 'O', 'KIM', 'REG', 'FRT-PC', 'ADC', 'FRT', 'NNN', 'BRX', 'KIM-PM', 'KIM-PL', 'EPRT', 'KRG', 'PECO', 'MAC', 'SKT', 'FCPT', 'AKR', 'UE', 'CURB', 'IVT', 'GTY', 'BFS-PD', 'NTST', 'ALEX', 'BFS', 'ALX', 'CBL', 'WSR', 'SITC', 'PINE', 'CDR-PC', 'CDR-PB', 'ADC-PA', 'BFS-PE', 'KIM-PN', 'REGCO', 'REGCP']

# %%
# Coleta os dados
tickers = yq.Ticker(lista_reits)

# Informações financeiras
financial_data = tickers.financial_data

# Informações de perfil (nome, setor, indústria)
summary_profile = tickers.summary_profile

# Informações de dividendos
dividends = tickers.key_stats

data = []

for ticker in lista_reits:
    try:
        f = financial_data.get(ticker, {})
        s = summary_profile.get(ticker, {})
        d = dividends.get(ticker, {})

        row = {
            'Ticker': ticker,
            'CompanyName': s.get('longName'),
            'Sector': s.get('sector'),
            'Industry': s.get('industry'),
            'PriceToEarnings': f.get('trailingPE'),
            'PriceToBook': f.get('priceToBook'),
            'DividendYield': f.get('dividendYield'),
            'MarketCap': f.get('marketCap'),
            'OperatingMargin': f.get('operatingMargins'),
            'DebtToEquity': f.get('debtToEquity'),
            'ReturnOnEquity': f.get('returnOnEquity'),
            'DividendRate': d.get('dividendRate'),
            'ForwardPE': d.get('forwardPE'),
            'Beta': d.get('beta'),
        }
        data.append(row)
        print("Inserido com sucesso: {}".format(row))
    except Exception as e:
        print(f"Erro ao processar {ticker}: {e}")

df = pd.DataFrame(data)
df.head()
# Out:
# Inserido com sucesso: {'Ticker': 'VICI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.76761, 'DebtToEquity': 65.738, 'ReturnOnEquity': 0.1012, 'DividendRate': None, 'ForwardPE': 11.24468, 'Beta': 0.724}
# Inserido com sucesso: {'Ticker': 'WPC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.49671, 'DebtToEquity': 94.044, 'ReturnOnEquity': 0.05014, 'DividendRate': None, 'ForwardPE': 22.62592, 'Beta': 0.811}
# Inserido com sucesso: {'Ticker': 'BNL', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.49897, 'DebtToEquity': 65.12, 'ReturnOnEquity': 0.03757, 'DividendRate': None, 'ForwardPE': 21.800194, 'Beta': 1.031}
# Inserido com sucesso: {'Ticker': 'ESRT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.14321, 'DebtToEquity': 116.804, 'ReturnOnEquity': 0.04895, 'DividendRate': None, 'ForwardPE': 95.75, 'Beta': 1.679}
# Inserido com sucesso: {'Ticker': 'GNL', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.31154, 'DebtToEquity': 170.955, 'ReturnOnEquity': -0.09877, 'DividendRate': None, 'ForwardPE': -12.933333, 'Beta': 1.209}
# Inserido com sucesso: {'Ticker': 'AAT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.25553, 'DebtToEquity': 148.047, 'ReturnOnEquity': 0.08866, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.185}
# Inserido com sucesso: {'Ticker': 'GNL-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.31154, 'DebtToEquity': 170.955, 'ReturnOnEquity': -0.09877, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.209}
# Inserido com sucesso: {'Ticker': 'SAFE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.80471003, 'DebtToEquity': 182.702, 'ReturnOnEquity': 0.0444, 'DividendRate': None, 'ForwardPE': 9.109703, 'Beta': 1.518}
# Inserido com sucesso: {'Ticker': 'AHH-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.13539, 'DebtToEquity': 166.298, 'ReturnOnEquity': 0.02444, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.138}
# Inserido com sucesso: {'Ticker': 'AHH', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.13539, 'DebtToEquity': 166.298, 'ReturnOnEquity': 0.02444, 'DividendRate': None, 'ForwardPE': 49.714287, 'Beta': 1.138}
# Erro ao processar GOODO: 'str' object has no attribute 'get'
# Inserido com sucesso: {'Ticker': 'GOOD', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.36380002, 'DebtToEquity': 211.656, 'ReturnOnEquity': 0.07637, 'DividendRate': None, 'ForwardPE': 66.74419, 'Beta': 1.159}
# Inserido com sucesso: {'Ticker': 'CTO', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.21985, 'DebtToEquity': 101.769, 'ReturnOnEquity': -0.0105, 'DividendRate': None, 'ForwardPE': -7.7232704, 'Beta': 0.571}
# Inserido com sucesso: {'Ticker': 'OLP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.39633, 'DebtToEquity': 133.156, 'ReturnOnEquity': 0.096949995, 'DividendRate': None, 'ForwardPE': 46.188683, 'Beta': 1.152}
# Inserido com sucesso: {'Ticker': 'FVR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.19841999, 'DebtToEquity': 63.315, 'ReturnOnEquity': -0.071490005, 'DividendRate': None, 'ForwardPE': -126.8739, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'CTO-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.21985, 'DebtToEquity': 101.769, 'ReturnOnEquity': -0.0105, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.571}
# Inserido com sucesso: {'Ticker': 'GNL-PB', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.31154, 'DebtToEquity': 170.955, 'ReturnOnEquity': -0.09877, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.209}
# Inserido com sucesso: {'Ticker': 'GNL-PD', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.31154, 'DebtToEquity': 170.955, 'ReturnOnEquity': -0.09877, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.209}
# Inserido com sucesso: {'Ticker': 'GNL-PE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.31154, 'DebtToEquity': 170.955, 'ReturnOnEquity': -0.09877, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.209}
# Inserido com sucesso: {'Ticker': 'GOODN', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.36380002, 'DebtToEquity': 211.656, 'ReturnOnEquity': 0.07637, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.159}
# Inserido com sucesso: {'Ticker': 'NXDT-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Diversified', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.24122, 'DebtToEquity': 43.402, 'ReturnOnEquity': -0.08444, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.834}
# Inserido com sucesso: {'Ticker': 'WELL', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.17048, 'DebtToEquity': 49.196, 'ReturnOnEquity': 0.0348, 'DividendRate': None, 'ForwardPE': 71.92541, 'Beta': 0.921}
# Inserido com sucesso: {'Ticker': 'VTR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.14152999, 'DebtToEquity': 108.897, 'ReturnOnEquity': 0.01381, 'DividendRate': None, 'ForwardPE': 98.89231, 'Beta': 0.908}
# Inserido com sucesso: {'Ticker': 'DOC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.1885, 'DebtToEquity': 103.846, 'ReturnOnEquity': 0.0332, 'DividendRate': None, 'ForwardPE': 71.54893, 'Beta': 1.013}
# Inserido com sucesso: {'Ticker': 'OHI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.56523997, 'DebtToEquity': 90.245, 'ReturnOnEquity': 0.10669, 'DividendRate': None, 'ForwardPE': 15.919183, 'Beta': 0.685}
# Inserido com sucesso: {'Ticker': 'CTRE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.69951, 'DebtToEquity': 27.887, 'ReturnOnEquity': 0.06956, 'DividendRate': None, 'ForwardPE': 16.753365, 'Beta': 0.865}
# Inserido com sucesso: {'Ticker': 'AHR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.07131, 'DebtToEquity': 79.509, 'ReturnOnEquity': -0.01773, 'DividendRate': None, 'ForwardPE': 49.914284, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'HR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.061890002, 'DebtToEquity': 97.86, 'ReturnOnEquity': -0.06763, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.709}
# Inserido com sucesso: {'Ticker': 'SBRA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.36883998, 'DebtToEquity': 88.887, 'ReturnOnEquity': 0.051469997, 'DividendRate': None, 'ForwardPE': 23.0, 'Beta': 0.814}
# Inserido com sucesso: {'Ticker': 'NHI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.62553, 'DebtToEquity': 92.144, 'ReturnOnEquity': 0.10309, 'DividendRate': None, 'ForwardPE': 21.918264, 'Beta': 0.774}
# Inserido com sucesso: {'Ticker': 'LTC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.55678004, 'DebtToEquity': 65.013, 'ReturnOnEquity': 0.09391, 'DividendRate': None, 'ForwardPE': 18.40038, 'Beta': 0.66}
# Inserido com sucesso: {'Ticker': 'SILA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.37921003, 'DebtToEquity': 43.23, 'ReturnOnEquity': 0.02475, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.146}
# Inserido com sucesso: {'Ticker': 'UHT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.37845, 'DebtToEquity': 220.394, 'ReturnOnEquity': 0.10152, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.956}
# Inserido com sucesso: {'Ticker': 'CHCT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.26398, 'DebtToEquity': 108.392, 'ReturnOnEquity': -0.0108, 'DividendRate': None, 'ForwardPE': 36.31111, 'Beta': 0.694}
# Inserido com sucesso: {'Ticker': 'GMRE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.27908, 'DebtToEquity': 127.907, 'ReturnOnEquity': 0.0143, 'DividendRate': None, 'ForwardPE': 12.979592, 'Beta': 1.181}
# Inserido com sucesso: {'Ticker': 'GMRE-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Healthcare Facilities', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.27908, 'DebtToEquity': 127.907, 'ReturnOnEquity': 0.0143, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.181}
# Inserido com sucesso: {'Ticker': 'HST', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.17768, 'DebtToEquity': 83.171, 'ReturnOnEquity': 0.09996, 'DividendRate': None, 'ForwardPE': 18.868614, 'Beta': 1.351}
# Inserido com sucesso: {'Ticker': 'RHP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.19770001, 'DebtToEquity': 364.889, 'ReturnOnEquity': 0.32494, 'DividendRate': None, 'ForwardPE': 27.666666, 'Beta': 1.591}
# Inserido com sucesso: {'Ticker': 'RLJ-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.07784, 'DebtToEquity': 104.122, 'ReturnOnEquity': 0.029059999, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.496}
# Inserido com sucesso: {'Ticker': 'APLE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.14434, 'DebtToEquity': 51.321, 'ReturnOnEquity': 0.05842, 'DividendRate': None, 'ForwardPE': 15.051949, 'Beta': 1.054}
# Inserido com sucesso: {'Ticker': 'PEB-PF', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': -0.03603, 'DebtToEquity': 95.818, 'ReturnOnEquity': -0.00168, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.751}
# Inserido com sucesso: {'Ticker': 'PEB-PE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': -0.03603, 'DebtToEquity': 95.818, 'ReturnOnEquity': -0.00168, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.751}
# Inserido com sucesso: {'Ticker': 'PK', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.096829996, 'DebtToEquity': 139.348, 'ReturnOnEquity': 0.03901, 'DividendRate': None, 'ForwardPE': 11.908046, 'Beta': 1.74}
# Inserido com sucesso: {'Ticker': 'SHO', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.07037, 'DebtToEquity': 41.077, 'ReturnOnEquity': 0.01674, 'DividendRate': None, 'ForwardPE': 42.666668, 'Beta': 1.287}
# Inserido com sucesso: {'Ticker': 'DRH', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.09718, 'DebtToEquity': 74.897, 'ReturnOnEquity': 0.03215, 'DividendRate': None, 'ForwardPE': 17.976469, 'Beta': 1.367}
# Inserido com sucesso: {'Ticker': 'XHR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.12550999, 'DebtToEquity': 115.227, 'ReturnOnEquity': 0.01907, 'DividendRate': None, 'ForwardPE': 64.368416, 'Beta': 1.669}
# Inserido com sucesso: {'Ticker': 'RLJ', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.07784, 'DebtToEquity': 104.122, 'ReturnOnEquity': 0.029059999, 'DividendRate': None, 'ForwardPE': 52.142857, 'Beta': 1.496}
# Inserido com sucesso: {'Ticker': 'PEB', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': -0.03603, 'DebtToEquity': 95.818, 'ReturnOnEquity': -0.00168, 'DividendRate': None, 'ForwardPE': -34.0, 'Beta': 1.751}
# Inserido com sucesso: {'Ticker': 'INN-PE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.10747, 'DebtToEquity': 105.442, 'ReturnOnEquity': 0.02656, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.62}
# Inserido com sucesso: {'Ticker': 'CLDT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.01741, 'DebtToEquity': 50.903, 'ReturnOnEquity': 0.013940001, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.457}
# Inserido com sucesso: {'Ticker': 'BHR-PD', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.17023, 'DebtToEquity': 175.746, 'ReturnOnEquity': 0.0198, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.135}
# Inserido com sucesso: {'Ticker': 'BHR-PB', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.17023, 'DebtToEquity': 175.746, 'ReturnOnEquity': 0.0198, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.135}
# Inserido com sucesso: {'Ticker': 'AHT-PD', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.06929, 'DebtToEquity': None, 'ReturnOnEquity': None, 'DividendRate': None, 'ForwardPE': None, 'Beta': 2.238}
# Inserido com sucesso: {'Ticker': 'AHT-PG', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.06929, 'DebtToEquity': None, 'ReturnOnEquity': None, 'DividendRate': None, 'ForwardPE': None, 'Beta': 2.238}
# Inserido com sucesso: {'Ticker': 'AHT-PI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.06929, 'DebtToEquity': None, 'ReturnOnEquity': None, 'DividendRate': None, 'ForwardPE': None, 'Beta': 2.238}
# Inserido com sucesso: {'Ticker': 'AHT-PF', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.06929, 'DebtToEquity': None, 'ReturnOnEquity': None, 'DividendRate': None, 'ForwardPE': None, 'Beta': 2.238}
# Inserido com sucesso: {'Ticker': 'AHT-PH', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.06929, 'DebtToEquity': None, 'ReturnOnEquity': None, 'DividendRate': None, 'ForwardPE': None, 'Beta': 2.238}
# Inserido com sucesso: {'Ticker': 'AHT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.06929, 'DebtToEquity': None, 'ReturnOnEquity': None, 'DividendRate': None, 'ForwardPE': None, 'Beta': 2.238}
# Inserido com sucesso: {'Ticker': 'CLDT-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.01741, 'DebtToEquity': 50.903, 'ReturnOnEquity': 0.013940001, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.457}
# Inserido com sucesso: {'Ticker': 'DRH-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.09718, 'DebtToEquity': 74.897, 'ReturnOnEquity': 0.03215, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.367}
# Inserido com sucesso: {'Ticker': 'INN-PF', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.10747, 'DebtToEquity': 105.442, 'ReturnOnEquity': 0.02656, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.62}
# Inserido com sucesso: {'Ticker': 'PEB-PG', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': -0.03603, 'DebtToEquity': 95.818, 'ReturnOnEquity': -0.00168, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.751}
# Inserido com sucesso: {'Ticker': 'PEB-PH', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': -0.03603, 'DebtToEquity': 95.818, 'ReturnOnEquity': -0.00168, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.751}
# Inserido com sucesso: {'Ticker': 'SHO-PH', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.07037, 'DebtToEquity': 41.077, 'ReturnOnEquity': 0.01674, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.287}
# Inserido com sucesso: {'Ticker': 'SHO-PI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Hotel & Motel', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.07037, 'DebtToEquity': 41.077, 'ReturnOnEquity': 0.01674, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.287}
# Inserido com sucesso: {'Ticker': 'PLD', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.39956, 'DebtToEquity': 56.643, 'ReturnOnEquity': 0.06829, 'DividendRate': None, 'ForwardPE': 33.220154, 'Beta': 1.268}
# Inserido com sucesso: {'Ticker': 'PSA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': 29.246647, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PH', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'EXR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.44397, 'DebtToEquity': 89.649, 'ReturnOnEquity': 0.063930005, 'DividendRate': None, 'ForwardPE': 31.741732, 'Beta': 1.131}
# Inserido com sucesso: {'Ticker': 'PSA-PK', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'LINE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.03339, 'DebtToEquity': 78.395, 'ReturnOnEquity': -0.09066, 'DividendRate': None, 'ForwardPE': -304.92856, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'CUBE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.42154998, 'DebtToEquity': 117.531, 'ReturnOnEquity': 0.13337, 'DividendRate': None, 'ForwardPE': 27.001596, 'Beta': 0.995}
# Inserido com sucesso: {'Ticker': 'EGP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.3775, 'DebtToEquity': 44.73, 'ReturnOnEquity': 0.07614, 'DividendRate': None, 'ForwardPE': 32.308224, 'Beta': 1.043}
# Inserido com sucesso: {'Ticker': 'REXR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.34952, 'DebtToEquity': 36.594, 'ReturnOnEquity': 0.03362, 'DividendRate': None, 'ForwardPE': 33.462475, 'Beta': 1.154}
# Inserido com sucesso: {'Ticker': 'FR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.38966998, 'DebtToEquity': 87.425, 'ReturnOnEquity': 0.102790006, 'DividendRate': None, 'ForwardPE': 25.991577, 'Beta': 1.1}
# Inserido com sucesso: {'Ticker': 'STAG', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.36054, 'DebtToEquity': 86.584, 'ReturnOnEquity': 0.07153, 'DividendRate': None, 'ForwardPE': 13.426415, 'Beta': 0.94}
# Inserido com sucesso: {'Ticker': 'TRNO', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.38931, 'DebtToEquity': 19.148, 'ReturnOnEquity': 0.05356, 'DividendRate': None, 'ForwardPE': 36.221462, 'Beta': 1.091}
# Inserido com sucesso: {'Ticker': 'NSA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.32489, 'DebtToEquity': 203.909, 'ReturnOnEquity': 0.05919, 'DividendRate': None, 'ForwardPE': 52.09043, 'Beta': 1.176}
# Inserido com sucesso: {'Ticker': 'COLD', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.05762, 'DebtToEquity': 122.607, 'ReturnOnEquity': -0.03549, 'DividendRate': None, 'ForwardPE': 31.865385, 'Beta': 0.858}
# Inserido com sucesso: {'Ticker': 'REXR-PB', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.34952, 'DebtToEquity': 36.594, 'ReturnOnEquity': 0.03362, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.154}
# Inserido com sucesso: {'Ticker': 'GRP-UN', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.75435996, 'DebtToEquity': 56.325, 'ReturnOnEquity': 0.05723, 'DividendRate': None, 'ForwardPE': None, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'LXP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.12189999, 'DebtToEquity': 73.237, 'ReturnOnEquity': 0.02851, 'DividendRate': None, 'ForwardPE': 22.88, 'Beta': 1.08}
# Inserido com sucesso: {'Ticker': 'NSA-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.32489, 'DebtToEquity': 203.909, 'ReturnOnEquity': 0.05919, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.176}
# Inserido com sucesso: {'Ticker': 'LXP-PC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.12189999, 'DebtToEquity': 73.237, 'ReturnOnEquity': 0.02851, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.08}
# Inserido com sucesso: {'Ticker': 'IIPR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.52273, 'DebtToEquity': 15.11, 'ReturnOnEquity': 0.07907, 'DividendRate': None, 'ForwardPE': 12.856811, 'Beta': 1.737}
# Inserido com sucesso: {'Ticker': 'IIPR-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.52273, 'DebtToEquity': 15.11, 'ReturnOnEquity': 0.07907, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.737}
# Inserido com sucesso: {'Ticker': 'PLYM', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': -0.01762, 'DebtToEquity': 123.506, 'ReturnOnEquity': 0.26775, 'DividendRate': None, 'ForwardPE': -31.153849, 'Beta': 1.153}
# Inserido com sucesso: {'Ticker': 'MDV', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.41535, 'DebtToEquity': 131.106, 'ReturnOnEquity': 0.012159999, 'DividendRate': None, 'ForwardPE': 98.96552, 'Beta': -0.319}
# Inserido com sucesso: {'Ticker': 'MDV-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.41535, 'DebtToEquity': 131.106, 'ReturnOnEquity': 0.012159999, 'DividendRate': None, 'ForwardPE': None, 'Beta': -0.319}
# Inserido com sucesso: {'Ticker': 'NSA-PB', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.32489, 'DebtToEquity': 203.909, 'ReturnOnEquity': 0.05919, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.176}
# Inserido com sucesso: {'Ticker': 'PSA-PF', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PG', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PJ', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PL', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PM', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PN', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PO', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PQ', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'PSA-PS', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45470002, 'DebtToEquity': 97.458, 'ReturnOnEquity': 0.20121, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.879}
# Inserido com sucesso: {'Ticker': 'REXR-PC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.34952, 'DebtToEquity': 36.594, 'ReturnOnEquity': 0.03362, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.154}
# Inserido com sucesso: {'Ticker': 'SMA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Industrial', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.26702, 'DebtToEquity': 242.03, 'ReturnOnEquity': -0.01545, 'DividendRate': None, 'ForwardPE': 82.42168, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'ARE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.20922, 'DebtToEquity': 61.193, 'ReturnOnEquity': 0.01476, 'DividendRate': None, 'ForwardPE': 23.803064, 'Beta': 1.267}
# Inserido com sucesso: {'Ticker': 'BXP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.28379, 'DebtToEquity': 209.428, 'ReturnOnEquity': 0.008, 'DividendRate': None, 'ForwardPE': 36.394596, 'Beta': 1.148}
# Inserido com sucesso: {'Ticker': 'VNO-PL', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.21332, 'DebtToEquity': 137.736, 'ReturnOnEquity': 0.02003, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.511}
# Inserido com sucesso: {'Ticker': 'VNO-PM', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.21332, 'DebtToEquity': 137.736, 'ReturnOnEquity': 0.02003, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.511}
# Inserido com sucesso: {'Ticker': 'VNO', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.21332, 'DebtToEquity': 137.736, 'ReturnOnEquity': 0.02003, 'DividendRate': None, 'ForwardPE': 289.76923, 'Beta': 1.511}
# Inserido com sucesso: {'Ticker': 'SLG-PI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.13978, 'DebtToEquity': 139.655, 'ReturnOnEquity': -0.00224, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.631}
# Inserido com sucesso: {'Ticker': 'CUZ', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.23462, 'DebtToEquity': 63.485, 'ReturnOnEquity': 0.0116, 'DividendRate': None, 'ForwardPE': 140.34999, 'Beta': 1.322}
# Inserido com sucesso: {'Ticker': 'SLG', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.13978, 'DebtToEquity': 139.655, 'ReturnOnEquity': -0.00224, 'DividendRate': None, 'ForwardPE': -66.89684, 'Beta': 1.631}
# Inserido com sucesso: {'Ticker': 'KRC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.27267, 'DebtToEquity': 84.697, 'ReturnOnEquity': 0.03937, 'DividendRate': None, 'ForwardPE': 37.00639, 'Beta': 1.205}
# Inserido com sucesso: {'Ticker': 'HIW', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.26179, 'DebtToEquity': 134.683, 'ReturnOnEquity': 0.07164, 'DividendRate': None, 'ForwardPE': 56.03774, 'Beta': 1.222}
# Inserido com sucesso: {'Ticker': 'CDP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.29202998, 'DebtToEquity': 157.589, 'ReturnOnEquity': 0.094189994, 'DividendRate': None, 'ForwardPE': 20.639097, 'Beta': 0.904}
# Inserido com sucesso: {'Ticker': 'DEI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.20922, 'DebtToEquity': 154.581, 'ReturnOnEquity': 0.01232, 'DividendRate': None, 'ForwardPE': -61.30714, 'Beta': 1.247}
# Inserido com sucesso: {'Ticker': 'DEA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.26908, 'DebtToEquity': 114.732, 'ReturnOnEquity': 0.01362, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.913}
# Inserido com sucesso: {'Ticker': 'JBGS', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': -0.039389998, 'DebtToEquity': 128.49, 'ReturnOnEquity': -0.082320005, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.219}
# Inserido com sucesso: {'Ticker': 'PGRE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.18312, 'DebtToEquity': 89.709, 'ReturnOnEquity': -0.014780001, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.339}
# Inserido com sucesso: {'Ticker': 'PDM', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.14644, 'DebtToEquity': 140.006, 'ReturnOnEquity': -0.03786, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.415}
# Inserido com sucesso: {'Ticker': 'NLOP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.26789, 'DebtToEquity': 25.331, 'ReturnOnEquity': -0.10187, 'DividendRate': None, 'ForwardPE': None, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'PKST', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.24691999, 'DebtToEquity': 129.135, 'ReturnOnEquity': -0.06159, 'DividendRate': None, 'ForwardPE': -73.89956, 'Beta': 1.773}
# Inserido com sucesso: {'Ticker': 'PSTL', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.29255, 'DebtToEquity': 98.295, 'ReturnOnEquity': 0.03413, 'DividendRate': None, 'ForwardPE': 54.621517, 'Beta': 0.786}
# Inserido com sucesso: {'Ticker': 'CIO-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.1688, 'DebtToEquity': 90.467, 'ReturnOnEquity': -0.024319999, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.639}
# Inserido com sucesso: {'Ticker': 'HPP-PC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': -0.14006, 'DebtToEquity': 149.114, 'ReturnOnEquity': -0.1247, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.452}
# Inserido com sucesso: {'Ticker': 'VNO-PN', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.21332, 'DebtToEquity': 137.736, 'ReturnOnEquity': 0.02003, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.511}
# Inserido com sucesso: {'Ticker': 'VNO-PO', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Office', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.21332, 'DebtToEquity': 137.736, 'ReturnOnEquity': 0.02003, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.511}
# Inserido com sucesso: {'Ticker': 'AVB', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.32197, 'DebtToEquity': 71.138, 'ReturnOnEquity': 0.096920006, 'DividendRate': None, 'ForwardPE': 36.459465, 'Beta': 0.872}
# Inserido com sucesso: {'Ticker': 'EQR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.25534, 'DebtToEquity': 70.333, 'ReturnOnEquity': 0.08901, 'DividendRate': None, 'ForwardPE': 53.868484, 'Beta': 0.919}
# Inserido com sucesso: {'Ticker': 'INVH', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.27612, 'DebtToEquity': 83.399, 'ReturnOnEquity': 0.048070002, 'DividendRate': None, 'ForwardPE': 43.517002, 'Beta': 0.817}
# Inserido com sucesso: {'Ticker': 'ESS', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.33332002, 'DebtToEquity': 118.416, 'ReturnOnEquity': 0.12810999, 'DividendRate': None, 'ForwardPE': 45.692085, 'Beta': 0.802}
# Inserido com sucesso: {'Ticker': 'MAA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.29018, 'DebtToEquity': 82.626, 'ReturnOnEquity': 0.09368, 'DividendRate': None, 'ForwardPE': 40.741222, 'Beta': 0.778}
# Inserido com sucesso: {'Ticker': 'SUI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.14104, 'DebtToEquity': 110.547, 'ReturnOnEquity': 0.017180001, 'DividendRate': None, 'ForwardPE': 53.41064, 'Beta': 0.86}
# Inserido com sucesso: {'Ticker': 'AMH', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.2393, 'DebtToEquity': 63.031, 'ReturnOnEquity': 0.060300004, 'DividendRate': None, 'ForwardPE': 51.71754, 'Beta': 0.773}
# Inserido com sucesso: {'Ticker': 'UDR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.19489, 'DebtToEquity': 136.541, 'ReturnOnEquity': 0.02848, 'DividendRate': None, 'ForwardPE': 68.47934, 'Beta': 0.833}
# Inserido com sucesso: {'Ticker': 'ELS', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.37637, 'DebtToEquity': 174.616, 'ReturnOnEquity': 0.229, 'DividendRate': None, 'ForwardPE': 26.454762, 'Beta': 0.749}
# Inserido com sucesso: {'Ticker': 'CPT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.1911, 'DebtToEquity': 79.752, 'ReturnOnEquity': 0.025999999, 'DividendRate': None, 'ForwardPE': 80.166214, 'Beta': 0.802}
# Inserido com sucesso: {'Ticker': 'MAA-PI', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.29018, 'DebtToEquity': 82.626, 'ReturnOnEquity': 0.09368, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.778}
# ...
# Inserido com sucesso: {'Ticker': 'CSR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.07867, 'DebtToEquity': 108.574, 'ReturnOnEquity': -0.01506, 'DividendRate': None, 'ForwardPE': -169.2328, 'Beta': 0.769}
# Inserido com sucesso: {'Ticker': 'UMH-PD', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.15526, 'DebtToEquity': 66.638, 'ReturnOnEquity': 0.03418, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.09}
# Inserido com sucesso: {'Ticker': 'BRT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.13696, 'DebtToEquity': 244.473, 'ReturnOnEquity': -0.04204, 'DividendRate': None, 'ForwardPE': -28.654545, 'Beta': 1.05}
# Inserido com sucesso: {'Ticker': 'MRP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Residential', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.55182, 'DebtToEquity': 6.178, 'ReturnOnEquity': -0.02409, 'DividendRate': None, 'ForwardPE': None, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'SPG', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.49396, 'DebtToEquity': 773.472, 'ReturnOnEquity': 0.67307, 'DividendRate': None, 'ForwardPE': 23.776684, 'Beta': 1.486}
# Inserido com sucesso: {'Ticker': 'SPG-PJ', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.49396, 'DebtToEquity': 773.472, 'ReturnOnEquity': 0.67307, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.486}
# Inserido com sucesso: {'Ticker': 'O', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.45145, 'DebtToEquity': 69.956, 'ReturnOnEquity': 0.02507, 'DividendRate': None, 'ForwardPE': 34.99771, 'Beta': 0.766}
# Inserido com sucesso: {'Ticker': 'KIM', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.33567002, 'DebtToEquity': 75.54, 'ReturnOnEquity': 0.05208, 'DividendRate': None, 'ForwardPE': 27.47054, 'Beta': 1.281}
# Inserido com sucesso: {'Ticker': 'REG', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.40598, 'DebtToEquity': 71.062, 'ReturnOnEquity': 0.05821, 'DividendRate': None, 'ForwardPE': 29.61458, 'Beta': 1.023}
# Inserido com sucesso: {'Ticker': 'FRT-PC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.34636003, 'DebtToEquity': 133.513, 'ReturnOnEquity': 0.094469994, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.122}
# Inserido com sucesso: {'Ticker': 'ADC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.48626, 'DebtToEquity': 52.674, 'ReturnOnEquity': 0.035469998, 'DividendRate': None, 'ForwardPE': 36.921177, 'Beta': 0.565}
# Inserido com sucesso: {'Ticker': 'FRT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.34636003, 'DebtToEquity': 133.513, 'ReturnOnEquity': 0.094469994, 'DividendRate': None, 'ForwardPE': 28.89472, 'Beta': 1.122}
# Inserido com sucesso: {'Ticker': 'NNN', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.62258, 'DebtToEquity': 103.102, 'ReturnOnEquity': 0.09352, 'DividendRate': None, 'ForwardPE': 20.260632, 'Beta': 0.916}
# Inserido com sucesso: {'Ticker': 'BRX', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.35446998, 'DebtToEquity': 174.372, 'ReturnOnEquity': 0.110139996, 'DividendRate': None, 'ForwardPE': 27.152077, 'Beta': 1.24}
# Inserido com sucesso: {'Ticker': 'KIM-PM', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.33567002, 'DebtToEquity': 75.54, 'ReturnOnEquity': 0.05208, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.281}
# Inserido com sucesso: {'Ticker': 'KIM-PL', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.33567002, 'DebtToEquity': 75.54, 'ReturnOnEquity': 0.05208, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.281}
# Inserido com sucesso: {'Ticker': 'EPRT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.62245, 'DebtToEquity': 56.183, 'ReturnOnEquity': 0.06019, 'DividendRate': None, 'ForwardPE': 25.22822, 'Beta': 1.126}
# Inserido com sucesso: {'Ticker': 'KRG', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.24209, 'DebtToEquity': 88.363, 'ReturnOnEquity': 0.00408, 'DividendRate': None, 'ForwardPE': 88.48, 'Beta': 1.109}
# Inserido com sucesso: {'Ticker': 'PECO', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.28004998, 'DebtToEquity': 86.917, 'ReturnOnEquity': 0.03004, 'DividendRate': None, 'ForwardPE': 46.657894, 'Beta': 0.458}
# Inserido com sucesso: {'Ticker': 'MAC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.12513, 'DebtToEquity': 193.07, 'ReturnOnEquity': -0.04599, 'DividendRate': None, 'ForwardPE': -111.58621, 'Beta': 2.135}
# Inserido com sucesso: {'Ticker': 'SKT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.28893, 'DebtToEquity': 249.834, 'ReturnOnEquity': 0.16044001, 'DividendRate': None, 'ForwardPE': 28.406654, 'Beta': 1.181}
# Inserido com sucesso: {'Ticker': 'FCPT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.53987, 'DebtToEquity': 84.373, 'ReturnOnEquity': 0.07616, 'DividendRate': None, 'ForwardPE': 24.47695, 'Beta': 0.868}
# Inserido com sucesso: {'Ticker': 'AKR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.19614, 'DebtToEquity': 60.538, 'ReturnOnEquity': 0.00132, 'DividendRate': None, 'ForwardPE': 60.187504, 'Beta': 1.409}
# Inserido com sucesso: {'Ticker': 'UE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.24523, 'DebtToEquity': 126.148, 'ReturnOnEquity': 0.06321, 'DividendRate': None, 'ForwardPE': 32.72072, 'Beta': 1.195}
# Inserido com sucesso: {'Ticker': 'CURB', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.13131, 'DebtToEquity': 5.114, 'ReturnOnEquity': 0.009190001, 'DividendRate': None, 'ForwardPE': 56.024693, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'IVT', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.19665001, 'DebtToEquity': 42.611, 'ReturnOnEquity': 0.01066, 'DividendRate': None, 'ForwardPE': 96.862076, 'Beta': -6.053}
# Inserido com sucesso: {'Ticker': 'GTY', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.52102, 'DebtToEquity': 95.629, 'ReturnOnEquity': 0.072340004, 'DividendRate': None, 'ForwardPE': 20.04137, 'Beta': 0.867}
# Inserido com sucesso: {'Ticker': 'BFS-PD', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.41187, 'DebtToEquity': 314.437, 'ReturnOnEquity': 0.12387, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.092}
# Inserido com sucesso: {'Ticker': 'NTST', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.32603002, 'DebtToEquity': 70.489, 'ReturnOnEquity': -0.00879, 'DividendRate': None, 'ForwardPE': 53.666664, 'Beta': 0.869}
# Inserido com sucesso: {'Ticker': 'ALEX', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.39828998, 'DebtToEquity': 45.053, 'ReturnOnEquity': 0.06469, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.05}
# Inserido com sucesso: {'Ticker': 'BFS', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.41187, 'DebtToEquity': 314.437, 'ReturnOnEquity': 0.12387, 'DividendRate': None, 'ForwardPE': 25.907694, 'Beta': 1.092}
# Inserido com sucesso: {'Ticker': 'ALX', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.34892, 'DebtToEquity': 618.999, 'ReturnOnEquity': 0.20165001, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.818}
# Inserido com sucesso: {'Ticker': 'CBL', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.14421, 'DebtToEquity': 757.875, 'ReturnOnEquity': 0.22044, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.565}
# Inserido com sucesso: {'Ticker': 'WSR', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.31503, 'DebtToEquity': 147.087, 'ReturnOnEquity': 0.07329, 'DividendRate': None, 'ForwardPE': 26.782608, 'Beta': 0.903}
# Inserido com sucesso: {'Ticker': 'SITC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.19132, 'DebtToEquity': 58.051, 'ReturnOnEquity': 0.42506, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.45}
# Inserido com sucesso: {'Ticker': 'PINE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.22167, 'DebtToEquity': 140.407, 'ReturnOnEquity': 0.0046900003, 'DividendRate': None, 'ForwardPE': -1532.0, 'Beta': 0.621}
# Inserido com sucesso: {'Ticker': 'CDR-PC', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.13608, 'DebtToEquity': 387.634, 'ReturnOnEquity': 0.10724, 'DividendRate': None, 'ForwardPE': None, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'CDR-PB', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.13608, 'DebtToEquity': 387.634, 'ReturnOnEquity': 0.10724, 'DividendRate': None, 'ForwardPE': None, 'Beta': None}
# Inserido com sucesso: {'Ticker': 'ADC-PA', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.48626, 'DebtToEquity': 52.674, 'ReturnOnEquity': 0.035469998, 'DividendRate': None, 'ForwardPE': None, 'Beta': 0.565}
# Inserido com sucesso: {'Ticker': 'BFS-PE', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.41187, 'DebtToEquity': 314.437, 'ReturnOnEquity': 0.12387, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.092}
# Inserido com sucesso: {'Ticker': 'KIM-PN', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.33567002, 'DebtToEquity': 75.54, 'ReturnOnEquity': 0.05208, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.281}
# Inserido com sucesso: {'Ticker': 'REGCO', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.40598, 'DebtToEquity': 71.062, 'ReturnOnEquity': 0.05821, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.023}
# Inserido com sucesso: {'Ticker': 'REGCP', 'CompanyName': None, 'Sector': 'Real Estate', 'Industry': 'REIT - Retail', 'PriceToEarnings': None, 'PriceToBook': None, 'DividendYield': None, 'MarketCap': None, 'OperatingMargin': 0.40598, 'DebtToEquity': 71.062, 'ReturnOnEquity': 0.05821, 'DividendRate': None, 'ForwardPE': None, 'Beta': 1.023}
#   Ticker CompanyName       Sector            Industry PriceToEarnings  \
# 0   VICI        None  Real Estate  REIT - Diversified            None
# 1    WPC        None  Real Estate  REIT - Diversified            None
# 2    BNL        None  Real Estate  REIT - Diversified            None
# 3   ESRT        None  Real Estate  REIT - Diversified            None
# 4    GNL        None  Real Estate  REIT - Diversified            None
#
#   PriceToBook DividendYield MarketCap  OperatingMargin  DebtToEquity  \
# 0        None          None      None          0.76761        65.738
# 1        None          None      None          0.49671        94.044
# 2        None          None      None          0.49897        65.120
# 3        None          None      None          0.14321       116.804
# 4        None          None      None          0.31154       170.955
#
#    ReturnOnEquity DividendRate  ForwardPE   Beta
# 0         0.10120         None  11.244680  0.724
# 1         0.05014         None  22.625920  0.811
# 2         0.03757         None  21.800194  1.031
# 3         0.04895         None  95.750000  1.679
# 4        -0.09877         None -12.933333  1.209

# %%
import pickle

with open("colunas_sugeridas_gpt.pkl", "rb") as f:
    feature_GPT = pickle.load(f)

# %%
dataJson = list()

for Reits in lista_reits:
    dataJson.append(yq.Ticker(Reits))
len(dataJson)
# Out:
# 189

# %%
def build_dataset_stocks(all_stock_data):
    for data_stocks in dataJson:
        try:
            balance_sheet = data_stocks.get_financial_data(types=feature_GPT, frequency='q', trailing=False)

            if isinstance(balance_sheet, str):
                continue

            start_date, end_date = balance_sheet['asOfDate'].iloc[[0, -1]]

            historic_value = data_stocks.history(start=start_date, end=end_date, interval='1mo')

            balance_sheet = (
                balance_sheet
                .fillna(0)  # Substitui NaNs por 0
                .rename(columns={'asOfDate': 'date'})  # Renomeia a coluna
                .assign(date=lambda df: pd.to_datetime(df['date']),  # Converte para datetime
                        year=lambda df: df['date'].dt.year)  # Extrai o ano
            )

            historic_value = (
                historic_value
                .reset_index()  # Transforma índices em colunas para evitar problemas
                .assign(date=lambda df: pd.to_datetime(df['date']),  # Converte para datetime
                        year=lambda df: df['date'].dt.year)  # Extrai o ano
            )

            complete_values = pd.merge(balance_sheet, historic_value, on='year', how='inner')

            complete_values.drop(columns=['date_x'], inplace=True)  # Remove data duplicada
            complete_values.rename(columns={'date_y': 'date'}, inplace=True)

            complete_values['symbol'] = historic_value['symbol']

            complete_values['date'] = pd.to_datetime(complete_values['date'])
            complete_values.set_index('date', inplace=True)

            all_stock_data.append(complete_values)
        except Exception as e:
            print(f"Error processing data for {data_stocks}: {e}")

# %%
all_info_stocks = []
build_dataset_stocks(all_info_stocks)
# Out:
# Error processing data for <yahooquery.ticker.Ticker object at 0x7efa98f26b30>: Failed to perform, curl: (35) TLS connect error: error:00000000:invalid library (0):OPENSSL_internal:invalid library (0). See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Error processing data for <yahooquery.ticker.Ticker object at 0x7efa98f8a350>: 'date'

# %%
all_info_stocks[1].head()
# Out:
#            periodType currencyCode  BasicEPS  CashAndCashEquivalents  \
# date
# 2024-04-01         3M          USD      0.72             776966000.0
# 2024-05-01         3M          USD      0.72             776966000.0
# 2024-06-01         3M          USD      0.72             776966000.0
# 2024-07-01         3M          USD      0.72             776966000.0
# 2024-08-01         3M          USD      0.72             776966000.0
#
#                    EBIT  EnterpriseValue  FreeCashFlow  GrossProfit  \
# date
# 2024-04-01  236411000.0     1.986074e+10  1.035547e+09  346702000.0
# 2024-05-01  236411000.0     1.986074e+10  1.035547e+09  346702000.0
# 2024-06-01  236411000.0     1.986074e+10  1.035547e+09  346702000.0
# 2024-07-01  236411000.0     1.986074e+10  1.035547e+09  346702000.0
# 2024-08-01  236411000.0     1.986074e+10  1.035547e+09  346702000.0
#
#             InvestedCapital  LongTermDebt  ...  \
# date                                       ...
# 2024-04-01     1.654627e+10  7.873215e+09  ...
# 2024-05-01     1.654627e+10  7.873215e+09  ...
# 2024-06-01     1.654627e+10  7.873215e+09  ...
# 2024-07-01     1.654627e+10  7.873215e+09  ...
# 2024-08-01     1.654627e+10  7.873215e+09  ...
#
#             TotalLiabilitiesNetMinorityInterest  year  symbol       open  \
# date
# 2024-04-01                         8.932332e+09  2024     WPC  56.279999
# 2024-05-01                         8.932332e+09  2024     WPC  54.049999
# 2024-06-01                         8.932332e+09  2024     WPC  56.759998
# 2024-07-01                         8.932332e+09  2024     WPC  54.790001
# 2024-08-01                         8.932332e+09  2024     WPC  58.660000
#
#                  high        low      close    volume   adjclose  dividends
# date
# 2024-04-01  57.770000  53.090000  54.840000  23140800  51.628487       0.00
# 2024-05-01  60.520000  53.380001  56.400002  25148200  53.097130       0.00
# 2024-06-01  57.919998  54.490002  55.049999  28744900  51.826183       0.87
# 2024-07-01  61.240002  54.139999  57.810001  24341700  55.288914       0.00
# 2024-08-01  60.570000  55.250000  60.020000  21607300  57.402534       0.00
#
# [5 rows x 23 columns]
